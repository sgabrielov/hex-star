# %%
from hexgrid import HexCoord, HexGrid

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
hg = HexGrid(5, set({HexCoord(2,1), HexCoord(2,2)}))
plot_hex_grid(hg.obstacles, HexCoord(2,0), 5, show_coords=False)
# Out:
# <Axes: title={'center': 'Hex grid (radius=5) centered at start=(2,0)'}, xlabel='x', ylabel='y'>

# %%
hg.neighbors(HexCoord(2,0))
# Out:
# [HexCoord(q=3, r=0),
#  HexCoord(q=3, r=-1),
#  HexCoord(q=2, r=-1),
#  HexCoord(q=1, r=0),
#  HexCoord(q=1, r=1)]
