# %%
# %load_ext autoreload
# %autoreload 2

# %%
from hexstar import HStarProblem, HStarSearch, h_cost_travel_time, travel_time, hex_manhattan_distance, f_cost, construct_full_solution, radius_from_angle, next_velocity
from hexgrid import (HexCoord, build_obstacle_map, HexGrid, Node, get_direction, 
    VelocityState, get_neighbors_at_radius, get_available_nodes_in_dir, get_direction_ray, 
    hex_segment_between, hdist, angle_abc, image_to_hex_obstacles, 
    unique_direction_vectors_up_to_n, circular_slice, make_grid_with_obstacles, euclid_center_distance, axial_to_xy)
from hexplot import plot_hex_grid, plot_hex_grid_fast, plot_hex_grid_2
from typing import Iterable, Optional, Set, List, Tuple, Callable, Dict, Literal
import math
import time

# %%
RADIUS = 100
MAP_JPG_SIZE = 1000 # largest dimension in px
a_max = 2
a_min = 89
ay_window_ms = 10

collision_radius = 2

jps_horizon = 1
n_step = 2

# %%
# hex_size = MAP_JPG_SIZE/RADIUS
# obs, start, goal = image_to_hex_obstacles(
#     "map3.png",
#     hex_radius_px=hex_size,
#     black_threshold=20
# )
# goal = HexCoord(-20, 90)

# %%
# hex_size = MAP_JPG_SIZE/RADIUS
# obs, start, goal = image_to_hex_obstacles(
#     "map2.png",
#     hex_radius_px=hex_size,
#     black_threshold=20
# )

# %%
# hex_size = 250/RADIUS
# obs, start, goal = image_to_hex_obstacles(
#     "map.png",
#     hex_radius_px=hex_size,
#     black_threshold=20
# )

# %%
obs_density = 0.03
hex_size = 1
n_obs = int(obs_density * 3 * RADIUS * (RADIUS + 1))
start = HexCoord(q=-RADIUS + 4, r=RADIUS - 8)
#start = HexCoord(0,0)
goal = HexCoord(q=RADIUS - 4, r=-RADIUS + 4)

obs = build_obstacle_map(
    center = HexCoord(0,0),
    radius = RADIUS,
    types = [("random_n", {"n": n_obs})],
    exclude=[start, goal],
    seed=42
)

# Draw the outer boundary
obs = set(obs.keys()).union(get_neighbors_at_radius(HexCoord(0,0), RADIUS))

# %%
hg = HexGrid(hex_size, obs)

problem = HStarProblem(
    hg, # hex grid
    start,
    goal,
    a_max,  # maximum acceleration (for acceleration phase)
    a_min,  # maximum deceleration (positive value; used with sign as needed)
    collision_radius = collision_radius,
    jps_horizon =  jps_horizon,
    ay_window_ms = 0,#ay_window_ms,
    n_step = n_step,   
    #start_v = VelocityState(0, None),
    goal_v = VelocityState(0, None)
)
#problem.goal_v=VelocityState(0, problem.DIRECTIONS.index(HexCoord(-1,2))) # approach from the northeast
hs = HStarSearch(
    problem = problem,
    heuristic = h_cost_travel_time
)

# %%
plot_hex_grid_fast(
    hg.obstacles.union(problem.collision_radius_map),
    start,
    HexCoord(0,0),
    RADIUS,
    goal = goal,
    figsize=(10,10),
    show_coords = False,
    #path = hexes_in_between_solid(HexCoord(q=0, r=0), HexCoord(q=14, r=10)),
    #path=problem.get_available_hexes_in_dir(start, problem.DIRECTIONS[0], ray_range = 50),
    #path=problem.actions(hs.root),
    #path=set(unique_direction_vectors_up_to_n(HexCoord(0,0), RADIUS)),
    facecolor_path = "#999999",
    #path = set([n.location for n in fsolution[-24:-21]]),
    #path = fsolution,
    linewidth=0,
    plt_title = f" Run {1} REVERSE",
    save_path=f"n-step-actions-jps",
)
# Out:
# <Axes: title={'center': 'Hex grid (radius=100) centered at (0,0)  Run 1 REVERSE'}, xlabel='x', ylabel='y'>

# %%
start = time.time()
fsolution = hs.search()
fsolution_path = construct_full_solution(fsolution)
search_time = time.time() - start
print(f'Search time: {search_time:.2f}s')
# Out:
# Search time: 0.74s

# %%
plot_hex_grid_fast(
    obs,
    start,
    HexCoord(0,0),
    RADIUS,
    goal = goal,
    figsize=(10,10),
    show_coords = False,
    path = set([n.location for n in fsolution]),
    linewidth=0,
    plt_title = f"Jump Points",
    save_path=f"jump-points-turning-r",
)
plot_hex_grid_fast(
    obs,
    start,
    HexCoord(0,0),
    RADIUS,
    goal = goal,
    figsize=(10,10),
    show_coords = False,
    path = fsolution_path,
    linewidth=0,
    plt_title = f"Solution",
    save_path=f"solution-turning-r",
)
# Out:
# <Axes: title={'center': 'Hex grid (radius=100) centered at (0,0) Solution'}, xlabel='x', ylabel='y'>

# %%
abc = {1,2,3}
defg = {6}
defg.union({1,2,3,4,5} - abc)
# Out:
# {4, 5, 6}

# %%
plot_hex_grid_2(
    obs,
    start,
    HexCoord(0,0),
    RADIUS,
    goal = goal,
    figsize=(10,10),
    show_coords = False,
    path = problem.expand_counter,
    linewidth=0,
    plt_title = f"Expand Counter",
    save_path=f"expand-counter",
)
# Out:
# <Axes: title={'center': 'Hex grid (radius=100) centered at (0,0) Expand Counter'}, xlabel='x', ylabel='y'>

# %%
def print_directions_info():
    for i in range(len(problem.DIRECTIONS_INFO)):
        direction = problem.DIRECTIONS[i]
        info = problem.DIRECTIONS_INFO[direction]
        print(f'====================================')
        print(f'Index: {i}')
        print(f'Direction: {direction}')
        print(f'Transition unit distance: {info.s}')
        print(f'Blockers: {info.blockers}')
    print(f'====================================')

#def print_directions_info():

# %%
[f.velocity.magnitude for f in fsolution]
# Out:
# [0,
#  3.4641016151377544,
#  4.350655494322149,
#  5.084919513674825,
#  5.72578463538636,
#  6.30181028920278,
#  6.829422827104611,
#  7.319099629165669,
#  7.778008910507145,
#  8.211310847983047,
#  8.622866638913045,
#  9.015654846030602,
#  9.392030426538799,
#  9.753893518144746,
#  10.102803669951308,
#  10.440059636987575,
#  10.999765689497988,
#  11.532339104616076,
#  12.041380536460805,
#  12.52975838649162,
#  12.803243669247749,
#  13.07100805922818,
#  13.33339622581897,
#  13.59071955949938,
#  13.843260503769859,
#  14.270103761894465,
#  14.684544983595323,
#  14.91858118607497,
#  15.14900220594695,
#  15.3759705731398,
#  15.599636992453913,
#  15.820141514114596,
#  16.03761455943145,
#  16.252177822900016,
#  16.463945068465172,
#  16.673022834738582,
#  16.87951106157965,
#  17.08350364849861,
#  17.285088953735265,
#  17.6287917946336,
#  17.96592052021106,
#  18.296838528514723,
#  18.621876923085406,
#  18.941338393538636,
#  19.255500516437916,
#  19.43456980148561,
#  19.61200414539758,
#  19.787847528959976,
#  20.088775717533593,
#  20.385262074090864,
#  20.677497668464802,
#  20.844354464929896,
#  21.00988615604374,
#  21.174123819421524,
#  21.33709733657485,
#  21.61646878540687,
#  21.776132025241424,
#  21.93463309953054,
#  22.091997022480705,
#  22.24824792363596,
#  22.403409091070213,
#  22.669643554803578,
#  22.932787421110575,
#  23.19294588666665,
#  23.341828166022534,
#  23.489766822222787,
#  23.636779573213307,
#  23.88927266772,
#  24.13912485142479,
#  24.386417297189716,
#  24.631227102860176,
#  24.771466485110427,
#  24.910916383249024,
#  25.049589982343026,
#  25.18750010449182,
#  25.324659222663808,
#  25.461079473862192,
#  25.596772671659256,
#  25.731750318135717,
#  25.866023615259323,
#  25.999603475734556,
#  26.229361046266995,
#  26.457123443326722,
#  26.68294175864851,
#  26.906864939926177,
#  27.12893991470047,
#  27.349211705192314,
#  27.56772353487731,
#  27.784516927516094,
#  27.999631799283154,
#  28.213106544573012,
#  28.42497811600615,
#  28.635282099106842,
#  28.756000836794122,
#  28.876214907012653,
#  28.99593058665742,
#  29.20212304929652,
#  29.406869785583353,
#  29.52443384413206,
#  29.641531624509657,
#  29.75816863110164,
#  29.874350260840103,
#  29.99008180611771,
#  30.105368457600846,
#  30.220215306946166,
#  30.3346273494246,
#  30.531780433319952,
#  30.645029281414214,
#  30.757861155955073,
#  30.87028062909836,
#  30.982292190048835,
#  31.093900247151957,
#  31.205109129918327,
#  31.315923090983404,
#  31.506936363924492,
#  31.69679856137505,
#  31.805899488470107,
#  31.914627453582135,
#  32.022986255675995,
#  32.209806716762735,
#  32.39554982912335,
#  32.58023401897558,
#  32.76387719320187,
#  32.94649675961336,
#  33.128109646208515,
#  33.30873231948664,
#  33.412570268710084,
#  33.51608651366929,
#  33.69462947105613,
#  33.79728182002275,
#  33.89962332611257,
#  34.00165679614143,
#  34.1033849949366,
#  34.278869119515406,
#  34.45345945058155,
#  34.627169507669365,
#  34.800012472883786,
#  34.972001202574425,
#  35.14314823849546,
#  35.241581566994725,
#  35.339740725894096,
#  35.43762799347176,
#  35.53524561662644,
#  35.63259581147919,
#  35.8005849709784,
#  35.89721559528705,
#  35.99358679993973,
#  36.08970066314032,
#  36.18555923549264,
#  36.35099307013973,
#  36.515677416492586,
#  36.67962236972113,
#  36.84283780038322,
#  37.005333361359504,
#  37.16711849451537,
#  37.32820243710306,
#  37.48859422791613,
#  37.58088477425222,
#  37.672949229465665,
#  37.76478924707741,
#  37.9233345959473,
#  38.014569708290125,
#  38.105586379646816,
#  38.19638617156079,
#  38.35314741409107,
#  38.509270527588555,
#  37.73592452822642,
#  35.298725189445584,
#  32.68026927673638,
#  29.832867780352597,
#  23.108440016582687,
#  18.867962264113206,
#  13.341664064126334,
#  0]

# %%
def print_velocities(path):
    for n in path:
        print(f'Velocity: {n.velocity.magnitude}, Position: {n.location}')

# %%
print_velocities(fsolution)
# Out:
# Velocity: 0, Position: HexCoord(q=-96, r=92)
# Velocity: 3.4641016151377544, Position: HexCoord(q=-94, r=91)
# Velocity: 4.350655494322149, Position: HexCoord(q=-93, r=91)
# Velocity: 5.084919513674825, Position: HexCoord(q=-92, r=91)
# Velocity: 5.72578463538636, Position: HexCoord(q=-91, r=91)
# Velocity: 6.30181028920278, Position: HexCoord(q=-90, r=90)
# Velocity: 6.829422827104611, Position: HexCoord(q=-89, r=89)
# Velocity: 7.319099629165669, Position: HexCoord(q=-88, r=88)
# Velocity: 7.778008910507145, Position: HexCoord(q=-87, r=87)
# Velocity: 8.211310847983047, Position: HexCoord(q=-86, r=86)
# Velocity: 8.622866638913045, Position: HexCoord(q=-85, r=85)
# Velocity: 9.015654846030602, Position: HexCoord(q=-84, r=84)
# Velocity: 9.392030426538799, Position: HexCoord(q=-83, r=83)
# Velocity: 9.753893518144746, Position: HexCoord(q=-82, r=82)
# Velocity: 10.102803669951308, Position: HexCoord(q=-81, r=81)
# Velocity: 10.440059636987575, Position: HexCoord(q=-80, r=80)
# Velocity: 10.999765689497988, Position: HexCoord(q=-79, r=78)
# Velocity: 11.532339104616076, Position: HexCoord(q=-78, r=76)
# Velocity: 12.041380536460805, Position: HexCoord(q=-77, r=74)
# Velocity: 12.52975838649162, Position: HexCoord(q=-76, r=72)
# Velocity: 12.803243669247749, Position: HexCoord(q=-75, r=71)
# Velocity: 13.07100805922818, Position: HexCoord(q=-74, r=70)
# Velocity: 13.33339622581897, Position: HexCoord(q=-73, r=69)
# Velocity: 13.59071955949938, Position: HexCoord(q=-72, r=68)
# Velocity: 13.843260503769859, Position: HexCoord(q=-71, r=67)
# Velocity: 14.270103761894465, Position: HexCoord(q=-70, r=65)
# Velocity: 14.684544983595323, Position: HexCoord(q=-69, r=63)
# Velocity: 14.91858118607497, Position: HexCoord(q=-69, r=62)
# Velocity: 15.14900220594695, Position: HexCoord(q=-68, r=61)
# Velocity: 15.3759705731398, Position: HexCoord(q=-67, r=60)
# Velocity: 15.599636992453913, Position: HexCoord(q=-66, r=59)
# Velocity: 15.820141514114596, Position: HexCoord(q=-65, r=58)
# Velocity: 16.03761455943145, Position: HexCoord(q=-64, r=57)
# Velocity: 16.252177822900016, Position: HexCoord(q=-63, r=56)
# Velocity: 16.463945068465172, Position: HexCoord(q=-62, r=55)
# Velocity: 16.673022834738582, Position: HexCoord(q=-61, r=54)
# Velocity: 16.87951106157965, Position: HexCoord(q=-60, r=53)
# Velocity: 17.08350364849861, Position: HexCoord(q=-59, r=52)
# Velocity: 17.285088953735265, Position: HexCoord(q=-58, r=51)
# Velocity: 17.6287917946336, Position: HexCoord(q=-57, r=49)
# Velocity: 17.96592052021106, Position: HexCoord(q=-56, r=47)
# Velocity: 18.296838528514723, Position: HexCoord(q=-55, r=45)
# Velocity: 18.621876923085406, Position: HexCoord(q=-54, r=43)
# Velocity: 18.941338393538636, Position: HexCoord(q=-53, r=41)
# Velocity: 19.255500516437916, Position: HexCoord(q=-52, r=39)
# Velocity: 19.43456980148561, Position: HexCoord(q=-51, r=38)
# Velocity: 19.61200414539758, Position: HexCoord(q=-50, r=37)
# Velocity: 19.787847528959976, Position: HexCoord(q=-49, r=36)
# Velocity: 20.088775717533593, Position: HexCoord(q=-47, r=35)
# Velocity: 20.385262074090864, Position: HexCoord(q=-45, r=34)
# Velocity: 20.677497668464802, Position: HexCoord(q=-43, r=33)
# Velocity: 20.844354464929896, Position: HexCoord(q=-42, r=33)
# Velocity: 21.00988615604374, Position: HexCoord(q=-41, r=33)
# Velocity: 21.174123819421524, Position: HexCoord(q=-40, r=33)
# Velocity: 21.33709733657485, Position: HexCoord(q=-39, r=33)
# Velocity: 21.61646878540687, Position: HexCoord(q=-37, r=32)
# Velocity: 21.776132025241424, Position: HexCoord(q=-36, r=31)
# Velocity: 21.93463309953054, Position: HexCoord(q=-35, r=30)
# Velocity: 22.091997022480705, Position: HexCoord(q=-34, r=30)
# Velocity: 22.24824792363596, Position: HexCoord(q=-33, r=30)
# Velocity: 22.403409091070213, Position: HexCoord(q=-32, r=30)
# Velocity: 22.669643554803578, Position: HexCoord(q=-31, r=31)
# Velocity: 22.932787421110575, Position: HexCoord(q=-30, r=32)
# Velocity: 23.19294588666665, Position: HexCoord(q=-29, r=33)
# Velocity: 23.341828166022534, Position: HexCoord(q=-28, r=33)
# Velocity: 23.489766822222787, Position: HexCoord(q=-27, r=33)
# Velocity: 23.636779573213307, Position: HexCoord(q=-26, r=33)
# Velocity: 23.88927266772, Position: HexCoord(q=-24, r=32)
# Velocity: 24.13912485142479, Position: HexCoord(q=-22, r=31)
# Velocity: 24.386417297189716, Position: HexCoord(q=-20, r=30)
# Velocity: 24.631227102860176, Position: HexCoord(q=-18, r=29)
# Velocity: 24.771466485110427, Position: HexCoord(q=-17, r=29)
# Velocity: 24.910916383249024, Position: HexCoord(q=-16, r=28)
# Velocity: 25.049589982343026, Position: HexCoord(q=-15, r=27)
# Velocity: 25.18750010449182, Position: HexCoord(q=-14, r=26)
# Velocity: 25.324659222663808, Position: HexCoord(q=-13, r=25)
# Velocity: 25.461079473862192, Position: HexCoord(q=-12, r=24)
# Velocity: 25.596772671659256, Position: HexCoord(q=-11, r=23)
# Velocity: 25.731750318135717, Position: HexCoord(q=-10, r=22)
# Velocity: 25.866023615259323, Position: HexCoord(q=-9, r=21)
# Velocity: 25.999603475734556, Position: HexCoord(q=-8, r=20)
# Velocity: 26.229361046266995, Position: HexCoord(q=-6, r=19)
# Velocity: 26.457123443326722, Position: HexCoord(q=-4, r=18)
# Velocity: 26.68294175864851, Position: HexCoord(q=-2, r=17)
# Velocity: 26.906864939926177, Position: HexCoord(q=0, r=16)
# Velocity: 27.12893991470047, Position: HexCoord(q=2, r=15)
# Velocity: 27.349211705192314, Position: HexCoord(q=4, r=14)
# Velocity: 27.56772353487731, Position: HexCoord(q=6, r=13)
# Velocity: 27.784516927516094, Position: HexCoord(q=8, r=12)
# Velocity: 27.999631799283154, Position: HexCoord(q=10, r=11)
# Velocity: 28.213106544573012, Position: HexCoord(q=12, r=10)
# Velocity: 28.42497811600615, Position: HexCoord(q=14, r=9)
# Velocity: 28.635282099106842, Position: HexCoord(q=16, r=8)
# Velocity: 28.756000836794122, Position: HexCoord(q=17, r=7)
# Velocity: 28.876214907012653, Position: HexCoord(q=18, r=6)
# Velocity: 28.99593058665742, Position: HexCoord(q=19, r=5)
# Velocity: 29.20212304929652, Position: HexCoord(q=20, r=3)
# Velocity: 29.406869785583353, Position: HexCoord(q=21, r=1)
# Velocity: 29.52443384413206, Position: HexCoord(q=22, r=0)
# Velocity: 29.641531624509657, Position: HexCoord(q=23, r=-1)
# Velocity: 29.75816863110164, Position: HexCoord(q=24, r=-2)
# Velocity: 29.874350260840103, Position: HexCoord(q=25, r=-3)
# Velocity: 29.99008180611771, Position: HexCoord(q=26, r=-4)
# Velocity: 30.105368457600846, Position: HexCoord(q=27, r=-5)
# Velocity: 30.220215306946166, Position: HexCoord(q=28, r=-6)
# Velocity: 30.3346273494246, Position: HexCoord(q=29, r=-7)
# Velocity: 30.531780433319952, Position: HexCoord(q=30, r=-9)
# Velocity: 30.645029281414214, Position: HexCoord(q=31, r=-10)
# Velocity: 30.757861155955073, Position: HexCoord(q=32, r=-11)
# Velocity: 30.87028062909836, Position: HexCoord(q=33, r=-12)
# Velocity: 30.982292190048835, Position: HexCoord(q=34, r=-13)
# Velocity: 31.093900247151957, Position: HexCoord(q=35, r=-14)
# Velocity: 31.205109129918327, Position: HexCoord(q=36, r=-15)
# Velocity: 31.315923090983404, Position: HexCoord(q=37, r=-16)
# Velocity: 31.506936363924492, Position: HexCoord(q=39, r=-17)
# Velocity: 31.69679856137505, Position: HexCoord(q=41, r=-18)
# Velocity: 31.805899488470107, Position: HexCoord(q=42, r=-19)
# Velocity: 31.914627453582135, Position: HexCoord(q=43, r=-20)
# Velocity: 32.022986255675995, Position: HexCoord(q=44, r=-21)
# Velocity: 32.209806716762735, Position: HexCoord(q=45, r=-23)
# Velocity: 32.39554982912335, Position: HexCoord(q=46, r=-25)
# Velocity: 32.58023401897558, Position: HexCoord(q=47, r=-27)
# Velocity: 32.76387719320187, Position: HexCoord(q=48, r=-29)
# Velocity: 32.94649675961336, Position: HexCoord(q=49, r=-31)
# Velocity: 33.128109646208515, Position: HexCoord(q=50, r=-33)
# Velocity: 33.30873231948664, Position: HexCoord(q=51, r=-35)
# Velocity: 33.412570268710084, Position: HexCoord(q=52, r=-36)
# Velocity: 33.51608651366929, Position: HexCoord(q=53, r=-37)
# Velocity: 33.69462947105613, Position: HexCoord(q=54, r=-39)
# Velocity: 33.79728182002275, Position: HexCoord(q=54, r=-40)
# Velocity: 33.89962332611257, Position: HexCoord(q=54, r=-41)
# Velocity: 34.00165679614143, Position: HexCoord(q=54, r=-42)
# Velocity: 34.1033849949366, Position: HexCoord(q=54, r=-43)
# Velocity: 34.278869119515406, Position: HexCoord(q=55, r=-45)
# Velocity: 34.45345945058155, Position: HexCoord(q=56, r=-47)
# Velocity: 34.627169507669365, Position: HexCoord(q=57, r=-49)
# Velocity: 34.800012472883786, Position: HexCoord(q=58, r=-51)
# Velocity: 34.972001202574425, Position: HexCoord(q=59, r=-53)
# Velocity: 35.14314823849546, Position: HexCoord(q=60, r=-55)
# Velocity: 35.241581566994725, Position: HexCoord(q=60, r=-56)
# Velocity: 35.339740725894096, Position: HexCoord(q=60, r=-57)
# Velocity: 35.43762799347176, Position: HexCoord(q=60, r=-58)
# Velocity: 35.53524561662644, Position: HexCoord(q=60, r=-59)
# Velocity: 35.63259581147919, Position: HexCoord(q=61, r=-60)
# Velocity: 35.8005849709784, Position: HexCoord(q=62, r=-62)
# Velocity: 35.89721559528705, Position: HexCoord(q=63, r=-63)
# Velocity: 35.99358679993973, Position: HexCoord(q=64, r=-64)
# Velocity: 36.08970066314032, Position: HexCoord(q=65, r=-65)
# Velocity: 36.18555923549264, Position: HexCoord(q=66, r=-66)
# Velocity: 36.35099307013973, Position: HexCoord(q=67, r=-68)
# Velocity: 36.515677416492586, Position: HexCoord(q=68, r=-70)
# Velocity: 36.67962236972113, Position: HexCoord(q=69, r=-72)
# Velocity: 36.84283780038322, Position: HexCoord(q=70, r=-74)
# Velocity: 37.005333361359504, Position: HexCoord(q=71, r=-76)
# Velocity: 37.16711849451537, Position: HexCoord(q=72, r=-78)
# Velocity: 37.32820243710306, Position: HexCoord(q=73, r=-80)
# Velocity: 37.48859422791613, Position: HexCoord(q=74, r=-82)
# Velocity: 37.58088477425222, Position: HexCoord(q=75, r=-83)
# Velocity: 37.672949229465665, Position: HexCoord(q=76, r=-84)
# Velocity: 37.76478924707741, Position: HexCoord(q=77, r=-85)
# Velocity: 37.9233345959473, Position: HexCoord(q=79, r=-86)
# Velocity: 38.014569708290125, Position: HexCoord(q=80, r=-87)
# Velocity: 38.105586379646816, Position: HexCoord(q=81, r=-88)
# Velocity: 38.19638617156079, Position: HexCoord(q=82, r=-89)
# Velocity: 38.35314741409107, Position: HexCoord(q=84, r=-90)
# Velocity: 38.509270527588555, Position: HexCoord(q=86, r=-91)
# Velocity: 37.73592452822642, Position: HexCoord(q=88, r=-92)
# Velocity: 35.298725189445584, Position: HexCoord(q=89, r=-92)
# Velocity: 32.68026927673638, Position: HexCoord(q=90, r=-92)
# Velocity: 29.832867780352597, Position: HexCoord(q=91, r=-92)
# Velocity: 23.108440016582687, Position: HexCoord(q=93, r=-93)
# Velocity: 18.867962264113206, Position: HexCoord(q=94, r=-94)
# Velocity: 13.341664064126334, Position: HexCoord(q=95, r=-95)
# Velocity: 0, Position: HexCoord(q=96, r=-96)

# %%
from typing import Sequence, Tuple, List

def velocity_profile_xy(path: Sequence) -> Tuple[List[float], List[float], List[int]]:
    """
    Returns:
      x_cum: cumulative hex distance traveled (same length as path)
      vels : velocity magnitudes (same length as path)
      segd : per-segment hex distances between consecutive points (len = len(path)-1)
    """
    if not path:
        return [], [], []

    vels = [n.velocity.magnitude for n in path]

    x_cum = [0.0]
    segd = []
    total = 0

    for prev, nxt in zip(path[:-1], path[1:]):
        d = hex_manhattan_distance(prev.location, nxt.location)
        segd.append(d)
        total += d
        x_cum.append(float(total))

    return x_cum, vels, segd

# %%
import matplotlib.pyplot as plt

def plot_velocity_profile(
    path,
    ax=None,
    marker="o",
    lw=2.0,
    color="#1f77b4",
    title="Velocity vs Path Distance",
    show=True,
    savepath=None,          # <-- NEW: e.g. "vel_profile.png" or Path(...)
    dpi=150,                # <-- NEW: file resolution
    bbox_inches="tight",    # <-- NEW: trims whitespace in saved image
    close=False             # <-- NEW: close figure after saving/showing (useful in batch)
):
    x, v, segd = velocity_profile_xy(path)

    fig = None
    if ax is None:
        fig, ax = plt.subplots(figsize=(9, 3.5))
    else:
        fig = ax.figure

    ax.plot(x, v, marker=marker, lw=lw, color=color)
    ax.set_xlabel("Cumulative hex distance traveled (steps)")
    ax.set_ylabel("Velocity")
    ax.set_title(title)
    ax.grid(True, alpha=0.25)

    # Optional: annotate segment distances (can be noisy; keep off by default)
    # for i, d in enumerate(segd, start=1):
    #     ax.text(x[i], v[i], str(d), fontsize=8, ha="left", va="bottom")

    # Layout before save/show so both look good
    if fig is not None:
        fig.tight_layout()

    # Optional save
    if savepath:
        fig.savefig(savepath, dpi=dpi, bbox_inches=bbox_inches)

    # Optional show
    if show:
        plt.show()

    # Optional close (handy for loops / notebooks to avoid too many open figures)
    if close and fig is not None:
        plt.close(fig)

    return ax

# %%
plot_velocity_profile(fsolution, savepath='vel-before.png')
# Out:
# <Axes: title={'center': 'Velocity vs Path Distance'}, xlabel='Cumulative hex distance traveled (steps)', ylabel='Velocity'>

# %%
new_path = problem.backtrack(fsolution[-1], 26, 10, transition_function = next_velocity)
new_soln = hs.reconstruct_path(new_path)
plot_velocity_profile(new_soln, savepath='vel-after.png')
# Out:
# <Axes: title={'center': 'Velocity vs Path Distance'}, xlabel='Cumulative hex distance traveled (steps)', ylabel='Velocity'>

# %%
o, c = hs.get_benchmarks()
plt.plot(o)

# %% [markdown]
# ### Benchmarking

# %%
{
    "length": float,          # total Euclidean length
    "turn_sum": float,        # sum of |turn angles|
    "curvature_sum": float,   # sum of |kappa|
    "curvature_sq": float,    # sum of kappa^2
    "max_curvature": float,   # worst local curvature
}
# Out:
# {'length': float,
#  'turn_sum': float,
#  'curvature_sum': float,
#  'curvature_sq': float,
#  'max_curvature': float}

# %%
def signed_turn_angle(
    a: HexCoord,
    b: HexCoord,
    c: HexCoord,
    *,
    hex_size: float = 1.0,
    degrees_out: bool = False,
) -> float:
    """
    Signed path turn angle at B for the path A -> B -> C.

    Convention
    ----------
    - 0      : straight
    - > 0    : left turn (counterclockwise in XY)
    - < 0    : right turn (clockwise in XY)
    - range  : [-pi, pi]

    Notes
    -----
    This is NOT the same as angle_abc(...), which returns the interior angle ∠ABC.
    Here we use the forward path directions AB and BC, so straight motion gives 0.
    """
    if a == b or b == c:
        raise ValueError("Turn angle undefined when A == B or B == C.")

    ax, ay = axial_to_xy(a, hex_size=hex_size)
    bx, by = axial_to_xy(b, hex_size=hex_size)
    cx, cy = axial_to_xy(c, hex_size=hex_size)

    # Forward path vectors
    ux, uy = (bx - ax), (by - ay)   # AB
    vx, vy = (cx - bx), (cy - by)   # BC

    nu = math.hypot(ux, uy)
    nv = math.hypot(vx, vy)
    if nu == 0.0 or nv == 0.0:
        raise ValueError("Turn angle undefined due to zero-length segment.")

    # Signed angle from u -> v
    cross = ux * vy - uy * vx
    dot = ux * vx + uy * vy
    theta = math.atan2(cross, dot)   # [-pi, pi], 0 = straight

    return math.degrees(theta) if degrees_out else theta


def unsigned_turn_angle(
    a: HexCoord,
    b: HexCoord,
    c: HexCoord,
    *,
    hex_size: float = 1.0,
    degrees_out: bool = False,
) -> float:
    """
    Unsigned path turn angle at B for A -> B -> C.

    Equivalent to:
        pi - angle_abc(a,b,c)
    because angle_abc returns the interior angle ∠ABC.
    """
    interior = angle_abc(a, b, c, hex_size=hex_size, degrees_out=False)
    turn = math.pi - interior
    # Clamp tiny negative due to floating point
    if turn < 0.0 and abs(turn) < 1e-12:
        turn = 0.0
    return math.degrees(turn) if degrees_out else turn


def curvature_from_turn_chord(
    a: HexCoord,
    b: HexCoord,
    c: HexCoord,
    *,
    hex_size: float = 1.0,
    signed: bool = False,
    chord: Literal["ab", "bc", "ac", "avg_adjacent"] = "avg_adjacent",
    eps: float = 1e-12,
) -> float:
    """
    Curvature approximation using heading change + chord length:

        kappa = 2 * sin(delta / 2) / d

    where delta is the path turn angle at B (0 for straight), and d is a chosen
    chord/segment length.

    Parameters
    ----------
    signed : bool
        If True, attach the sign from the turn direction (left positive, right negative).
    chord : {"ab", "bc", "ac", "avg_adjacent"}
        Which geometric length to use as d:
          - "ab": length of segment A->B
          - "bc": length of segment B->C
          - "ac": chord from A to C
          - "avg_adjacent": 0.5 * (|AB| + |BC|)   [recommended default]

    Notes
    -----
    - For equal-length single-step paths on your hex grid, AB and BC will be the same.
    - "avg_adjacent" is usually the cleanest when segment lengths may differ.
    """
    delta_signed = signed_turn_angle(a, b, c, hex_size=hex_size, degrees_out=False)
    delta = abs(delta_signed)

    if delta <= eps:
        return 0.0

    ab = euclid_center_distance(a, b, hex_size=hex_size)
    bc = euclid_center_distance(b, c, hex_size=hex_size)
    ac = euclid_center_distance(a, c, hex_size=hex_size)

    if chord == "ab":
        d = ab
    elif chord == "bc":
        d = bc
    elif chord == "ac":
        d = ac
    elif chord == "avg_adjacent":
        d = 0.5 * (ab + bc)
    else:
        raise ValueError(f"Unsupported chord={chord!r}")

    if d <= eps:
        raise ValueError("Curvature undefined due to zero chord length.")

    kappa = 2.0 * math.sin(delta / 2.0) / d
    if signed:
        kappa = math.copysign(kappa, delta_signed)
    return kappa


def curvature_three_points(
    a: HexCoord,
    b: HexCoord,
    c: HexCoord,
    *,
    hex_size: float = 1.0,
    signed: bool = False,
    eps: float = 1e-12,
) -> float:
    """
    Three-point geometric curvature for the path A -> B -> C using the circumcircle.

    Formula:
        kappa = 4 * Area(ABC) / (|AB| * |BC| * |AC|)

    Sign convention
    ---------------
    - positive for left turn
    - negative for right turn

    Returns
    -------
    float
        Curvature magnitude (or signed curvature if signed=True).
        Returns 0.0 for collinear points.

    Notes
    -----
    This is usually the most geometric "continuous approximation" for curvature
    of a polyline through three points.
    """
    if a == b or b == c or a == c:
        raise ValueError("Three distinct points are required for three-point curvature.")

    ax, ay = axial_to_xy(a, hex_size=hex_size)
    bx, by = axial_to_xy(b, hex_size=hex_size)
    cx, cy = axial_to_xy(c, hex_size=hex_size)

    ab = euclid_center_distance(a, b, hex_size=hex_size)
    bc = euclid_center_distance(b, c, hex_size=hex_size)
    ac = euclid_center_distance(a, c, hex_size=hex_size)

    if ab <= eps or bc <= eps or ac <= eps:
        raise ValueError("Curvature undefined due to zero-length side.")

    # 2 * signed area of triangle ABC
    cross = (bx - ax) * (cy - ay) - (by - ay) * (cx - ax)

    if abs(cross) <= eps:
        return 0.0

    # Since Area = |cross| / 2, then:
    #   4*Area / (ab*bc*ac) = 2*|cross| / (ab*bc*ac)
    kappa = 2.0 * abs(cross) / (ab * bc * ac)

    if signed:
        kappa = math.copysign(kappa, cross)

    return kappa


def turning_radius_three_points(
    a: HexCoord,
    b: HexCoord,
    c: HexCoord,
    *,
    hex_size: float = 1.0,
    eps: float = 1e-12,
) -> float:
    """
    Radius of curvature for A -> B -> C, using the circumcircle.

    Returns
    -------
    float
        Radius R = 1 / kappa, or math.inf if the points are collinear.
    """
    kappa = curvature_three_points(a, b, c, hex_size=hex_size, signed=False, eps=eps)
    if abs(kappa) <= eps:
        return math.inf
    return 1.0 / kappa

# %%
def evaluate_path(
    path: List[HexCoord],
    *,
    hex_size: float = 1.0,
) -> Dict[str, float]:

    if len(path) < 2:
        return {
            "length": 0.0,
            "turn_sum": 0.0,
            "curvature_sum": 0.0,
            "curvature_sq": 0.0,
            "max_curvature": 0.0,
        }

    # --- length ---
    length = 0.0
    for i in range(len(path) - 1):
        length += euclid_center_distance(path[i], path[i+1], hex_size=hex_size)

    # --- curvature / turning ---
    turn_sum = 0.0
    curvature_sum = 0.0
    curvature_sq = 0.0
    max_curv = 0.0

    for i in range(1, len(path) - 1):
        a, b, c = path[i-1], path[i], path[i+1]

        # turn angle (0 if straight)
        theta = abs(unsigned_turn_angle(a, b, c, hex_size=hex_size))

        # curvature (your geometric version)
        kappa = abs(curvature_three_points(a, b, c, hex_size=hex_size))

        turn_sum += theta
        curvature_sum += kappa
        curvature_sq += kappa * kappa
        max_curv = max(max_curv, kappa)

    return {
        "length": length,
        "turn_sum": turn_sum,
        "curvature_sum": curvature_sum,
        "curvature_sq": curvature_sq,
        "max_curvature": max_curv,
    }

# %%
def normalize_metrics(metrics):
    L = metrics["length"]
    
    return {
        "length": L,
        "turn_per_length": metrics["turn_sum"] / L if L > 0 else 0.0,
        "curv_per_length": metrics["curvature_sum"] / L if L > 0 else 0.0,
        "curv_sq_per_length": metrics["curvature_sq"] / L if L > 0 else 0.0,
        "max_curvature": metrics["max_curvature"],
    }

# %%
raw = evaluate_path([f.location for f in fsolution], hex_size=problem.grid.hex_size)
norm = normalize_metrics(raw)
print(f'Raw: {raw}\nNorm: {norm}')
# Out:
# Raw: {'length': 387.13328398716345, 'turn_sum': 25.656340391746813, 'curvature_sum': 11.397249065151822, 'curvature_sq': 3.523809523809522, 'max_curvature': 0.5773502691896264}
# Norm: {'length': 387.13328398716345, 'turn_per_length': 0.06627262871202137, 'curv_per_length': 0.029440116715796855, 'curv_sq_per_length': 0.009102316100328807, 'max_curvature': 0.5773502691896264}

# %%
def run_benchmark(scenarios, num_runs=20):
    results = []

    for config in scenarios:
        for seed in range(num_runs):            

            path = run_scenario(config, seed=seed)

            if not path:
                continue  # skip failures or track success rate separately

            raw = evaluate_path([p.location for p in path], hex_size=problem.grid.hex_size)
            norm = normalize_metrics(raw)

            results.append(norm)

    return results

# %%
AGENT_DEFAULTS = {
    'a_max': 5,
    'a_min': 10,
    'max_turn_gs': 9,
    'collision_radius': 0,
    'start_v': VelocityState(0, None),
    'goal_v': None,
}

SEARCH_DEFAULTS = {
    'jps_horizon': None,
    'n_step': 2,
}

def run_scenario(map_scenario, agent_parms = AGENT_DEFAULTS, search_parms = SEARCH_DEFAULTS, seed=None):
    if seed is None:
        map_scenario.get("seed", None)
    hg = make_grid_with_obstacles(
        hex_size=1.0,
        center=map_scenario["center"],
        radius=map_scenario["radius"],
        types=map_scenario["types"],
        seed=seed,
    )    


    problem = HStarProblem(
        hg, # hex grid
        map_scenario['start'],
        map_scenario['goal'],
        agent_parms['a_max'],  # maximum acceleration (for acceleration phase)
        agent_parms['a_min'],  # maximum deceleration (positive value; used with sign as needed)
        collision_radius = agent_parms['collision_radius'],
        jps_horizon = search_parms['jps_horizon'],
        ay_window_ms = agent_parms['max_turn_gs'],
        n_step = search_parms['n_step'],   
        start_v = agent_parms['start_v'],
        goal_v = agent_parms['start_v']
    )
    #problem.goal_v=VelocityState(0, problem.DIRECTIONS.index(HexCoord(-1,2))) # approach from the northeast
    hs = HStarSearch(
        problem = problem,
        heuristic = h_cost_travel_time
    )

    return hs.search()

# %%
def summarize(results: List[Dict[str, float]]):
    keys = results[0].keys()
    summary = {}

    for k in keys:
        vals = [r[k] for r in results]
        summary[k] = {
            "mean": sum(vals) / len(vals),
            "min": min(vals),
            "max": max(vals),
        }

    return summary

# %%
def generate_scenarios():
    center = HexCoord(0, 0)

    return [

        # -------------------------
        # OPEN FIELD (no guaranteed corridor)
        # -------------------------
        {
            "name": "sparse_random",
            "center": center,
            "radius": 30,
            "start": HexCoord(-25, 0),
            "goal": HexCoord(25, 0),
            "types": [
                ("random_n", {"n": 250}, "add"),  # ~0.12 density
            ],
        },

        # -------------------------
        # CLUTTERED BUT SOLVABLE
        # -------------------------
        {
            "name": "cluttered_with_bias",
            "center": center,
            "radius": 30,
            "start": HexCoord(-25, -5),
            "goal": HexCoord(25, 5),
            "types": [
                ("random_n", {"n": 300}, "add"),  # ~0.15

                # carve a light corridor after noise
                ("track", {
                    "start": HexCoord(-25, -5),
                    "goal": HexCoord(25, 5),
                    "thickness": 2,
                    "min_turns": 4,
                }, "carve"),
            ],
        },
    ]

# %%
def plot_map_config(
    config: Dict,
    *,
    hex_size: float = 1.0,
    show_path: bool = False,
    figsize=(8, 8),
    save_path: Optional[str] = None,
):
    """
    Visualize a scenario config using plot_hex_grid_2.

    Parameters
    ----------
    config : Dict
        Scenario config from generate_scenarios()
    hex_size : float
        Hex size passed to grid + plotting
    show_path : bool
        If True and planner_fn provided, overlay computed path
    figsize : tuple
        Figure size
    save_path : Optional[str]
        If provided, saves image

    Returns
    -------
    ax : matplotlib Axes
    """
    # --- Build grid ---
    grid = make_grid_with_obstacles(
        hex_size=hex_size,
        center=config["center"],
        radius=config["radius"],
        types=config["types"],
        exclude=[config["start"], config["goal"]],
        seed=config.get("seed", None),
    )

    obstacles = set(grid.obstacles.keys())

    path = None


    # --- Plot ---
    ax = plot_hex_grid_2(
        obstacles=obstacles,
        start=config["start"],
        goal=config["goal"],
        center=config["center"],
        radius=config["radius"],
        hex_size=hex_size,
        path=path,
        figsize=figsize,
        plt_title=f"[{config.get('name','scenario')}]",
        save_path=save_path,
    )

    return ax

# %%
scenarios = generate_scenarios()

# %%
for c in scenarios:
    plot_map_config(c, hex_size=problem.grid.hex_size)

# %%
res_hstar = run_benchmark([scenarios[1]], num_runs=1)

print("H*", summarize(res_hstar))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 res_hstar = run_benchmark([scenarios[1]], num_runs=1)
#       3 print("H*", summarize(res_hstar))
#
# Cell In[93], line 12, in run_benchmark(scenarios, num_runs)
#       9 if not path:
#      10     continue  # skip failures or track success rate separately
# ---> 12 raw = evaluate_path([p.location for p in path], hex_size=problem.hex_size)
#      13 norm = normalize_metrics(raw)
#      15 results.append(norm)
#
# AttributeError: 'HStarProblem' object has no attribute 'hex_size'

# %%
res_hstar
# Out:
# []
